# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestRegressor
import os
import warnings
warnings.filterwarnings("ignore")
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv(r"C:\Users\ADYTHYA ANI\Downloads\retail_store_inventory.csv")
data
# Out:
#              Date Store ID Product ID     Category Region  Inventory Level  \
# 0      2022-01-01     S001      P0001    Groceries  North              231
# 1      2022-01-01     S001      P0002         Toys  South              204
# 2      2022-01-01     S001      P0003         Toys   West              102
# 3      2022-01-01     S001      P0004         Toys  North              469
# 4      2022-01-01     S001      P0005  Electronics   East              166
# ...           ...      ...        ...          ...    ...              ...
# 73095  2024-01-01     S005      P0016    Furniture   East               96
# 73096  2024-01-01     S005      P0017         Toys  North              313
# 73097  2024-01-01     S005      P0018     Clothing   West              278
# 73098  2024-01-01     S005      P0019         Toys   East              374
# 73099  2024-01-01     S005      P0020    Groceries   East              117
#
#        Units Sold  Units Ordered  Demand Forecast  Price  Discount  \
# 0             127             55           135.47  33.50        20
# 1             150             66           144.04  63.01        20
# 2              65             51            74.02  27.99        10
# 3              61            164            62.18  32.72        10
# 4              14            135             9.26  73.64         0
# ...           ...            ...              ...    ...       ...
# 73095           8            127            18.46  73.73        20
# 73096          51            101            48.43  82.57        10
# 73097          36            151            39.65  11.11        10
# 73098         264             21           270.52  53.14        20
# 73099           6            165             2.33  78.39        20
#
#       Weather Condition  Holiday/Promotion  Competitor Pricing Seasonality
# 0                 Rainy                  0               29.69      Autumn
# 1                 Sunny                  0               66.16      Autumn
# 2                 Sunny                  1               31.32      Summer
# 3                Cloudy                  1               34.74      Autumn
# 4                 Sunny                  0               68.95      Summer
# ...                 ...                ...                 ...         ...
# 73095             Snowy                  0               72.45      Winter
# 73096            Cloudy                  0               83.78      Autumn
# 73097             Rainy                  0               10.91      Winter
# 73098             Rainy                  0               55.80      Spring
# 73099             Rainy                  1               79.52      Spring
#
# [73100 rows x 15 columns]

# %%
data1=data.drop(["Date","Store ID","Product ID"],axis=1)
data1
# Out:
#           Category Region  Inventory Level  Units Sold  Units Ordered  \
# 0        Groceries  North              231         127             55
# 1             Toys  South              204         150             66
# 2             Toys   West              102          65             51
# 3             Toys  North              469          61            164
# 4      Electronics   East              166          14            135
# ...            ...    ...              ...         ...            ...
# 73095    Furniture   East               96           8            127
# 73096         Toys  North              313          51            101
# 73097     Clothing   West              278          36            151
# 73098         Toys   East              374         264             21
# 73099    Groceries   East              117           6            165
#
#        Demand Forecast  Price  Discount Weather Condition  Holiday/Promotion  \
# 0               135.47  33.50        20             Rainy                  0
# 1               144.04  63.01        20             Sunny                  0
# 2                74.02  27.99        10             Sunny                  1
# 3                62.18  32.72        10            Cloudy                  1
# 4                 9.26  73.64         0             Sunny                  0
# ...                ...    ...       ...               ...                ...
# 73095            18.46  73.73        20             Snowy                  0
# 73096            48.43  82.57        10            Cloudy                  0
# 73097            39.65  11.11        10             Rainy                  0
# 73098           270.52  53.14        20             Rainy                  0
# 73099             2.33  78.39        20             Rainy                  1
#
#        Competitor Pricing Seasonality
# 0                   29.69      Autumn
# 1                   66.16      Autumn
# 2                   31.32      Summer
# 3                   34.74      Autumn
# 4                   68.95      Summer
# ...                   ...         ...
# 73095               72.45      Winter
# 73096               83.78      Autumn
# 73097               10.91      Winter
# 73098               55.80      Spring
# 73099               79.52      Spring
#
# [73100 rows x 12 columns]

# %%
data.describe()
# Out:
#        Inventory Level    Units Sold  Units Ordered  Demand Forecast  \
# count     73100.000000  73100.000000   73100.000000     73100.000000
# mean        274.469877    136.464870     110.004473       141.494720
# std         129.949514    108.919406      52.277448       109.254076
# min          50.000000      0.000000      20.000000        -9.990000
# 25%         162.000000     49.000000      65.000000        53.670000
# 50%         273.000000    107.000000     110.000000       113.015000
# 75%         387.000000    203.000000     155.000000       208.052500
# max         500.000000    499.000000     200.000000       518.550000
#
#               Price      Discount  Holiday/Promotion  Competitor Pricing
# count  73100.000000  73100.000000       73100.000000        73100.000000
# mean      55.135108     10.009508           0.497305           55.146077
# std       26.021945      7.083746           0.499996           26.191408
# min       10.000000      0.000000           0.000000            5.030000
# 25%       32.650000      5.000000           0.000000           32.680000
# 50%       55.050000     10.000000           0.000000           55.010000
# 75%       77.860000     15.000000           1.000000           77.820000
# max      100.000000     20.000000           1.000000          104.940000

# %%
data.isnull().sum()
# Out:
# Date                  0
# Store ID              0
# Product ID            0
# Category              0
# Region                0
# Inventory Level       0
# Units Sold            0
# Units Ordered         0
# Demand Forecast       0
# Price                 0
# Discount              0
# Weather Condition     0
# Holiday/Promotion     0
# Competitor Pricing    0
# Seasonality           0
# dtype: int64

# %%
data.shape
# Out:
# (73100, 15)

# %%
data.head(5)
# Out:
#          Date Store ID Product ID     Category Region  Inventory Level  \
# 0  2022-01-01     S001      P0001    Groceries  North              231
# 1  2022-01-01     S001      P0002         Toys  South              204
# 2  2022-01-01     S001      P0003         Toys   West              102
# 3  2022-01-01     S001      P0004         Toys  North              469
# 4  2022-01-01     S001      P0005  Electronics   East              166
#
#    Units Sold  Units Ordered  Demand Forecast  Price  Discount  \
# 0         127             55           135.47  33.50        20
# 1         150             66           144.04  63.01        20
# 2          65             51            74.02  27.99        10
# 3          61            164            62.18  32.72        10
# 4          14            135             9.26  73.64         0
#
#   Weather Condition  Holiday/Promotion  Competitor Pricing Seasonality
# 0             Rainy                  0               29.69      Autumn
# 1             Sunny                  0               66.16      Autumn
# 2             Sunny                  1               31.32      Summer
# 3            Cloudy                  1               34.74      Autumn
# 4             Sunny                  0               68.95      Summer

# %%
data.tail(5)
# Out:
#              Date Store ID Product ID   Category Region  Inventory Level  \
# 73095  2024-01-01     S005      P0016  Furniture   East               96
# 73096  2024-01-01     S005      P0017       Toys  North              313
# 73097  2024-01-01     S005      P0018   Clothing   West              278
# 73098  2024-01-01     S005      P0019       Toys   East              374
# 73099  2024-01-01     S005      P0020  Groceries   East              117
#
#        Units Sold  Units Ordered  Demand Forecast  Price  Discount  \
# 73095           8            127            18.46  73.73        20
# 73096          51            101            48.43  82.57        10
# 73097          36            151            39.65  11.11        10
# 73098         264             21           270.52  53.14        20
# 73099           6            165             2.33  78.39        20
#
#       Weather Condition  Holiday/Promotion  Competitor Pricing Seasonality
# 73095             Snowy                  0               72.45      Winter
# 73096            Cloudy                  0               83.78      Autumn
# 73097             Rainy                  0               10.91      Winter
# 73098             Rainy                  0               55.80      Spring
# 73099             Rainy                  1               79.52      Spring

# %%
data["Demand Forecast"].value_counts()
# Out:
# Demand Forecast
# 46.06     12
# 21.84     12
# 33.84     11
# 17.33     11
# 95.24     11
#           ..
# 198.84     1
# 247.78     1
# 389.58     1
# 271.09     1
# 277.27     1
# Name: count, Length: 31608, dtype: int64

# %%
data.groupby("Demand Forecast").mean(numeric_only=True)
# Out:
#                  Inventory Level  Units Sold  Units Ordered  Price  Discount  \
# Demand Forecast
# -9.99                      190.0         0.0           87.0  77.12       0.0
# -9.97                       52.0         0.0          142.0  19.30       5.0
# -9.79                      182.0         0.0           33.0  62.77      15.0
# -9.67                       64.0         0.0          156.0  19.54      20.0
# -9.62                      220.0         0.0          184.0  54.97      15.0
# ...                          ...         ...            ...    ...       ...
#  504.76                    500.0       488.0          100.0  18.45      10.0
#  505.39                    499.0       488.0          116.0  88.48      15.0
#  506.37                    494.5       491.5           87.5  76.16      15.0
#  512.36                    497.0       493.0           25.0  55.09       0.0
#  518.55                    499.0       499.0           84.0  19.95      10.0
#
#                  Holiday/Promotion  Competitor Pricing
# Demand Forecast
# -9.99                          0.0              74.900
# -9.97                          0.0              23.900
# -9.79                          0.0              65.730
# -9.67                          0.0              16.120
# -9.62                          0.0              51.630
# ...                            ...                 ...
#  504.76                        0.0              13.460
#  505.39                        1.0              90.660
#  506.37                        0.5              74.715
#  512.36                        1.0              59.820
#  518.55                        0.0              16.000
#
# [31608 rows x 7 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73100 entries, 0 to 73099
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                73100 non-null  object
#  1   Store ID            73100 non-null  object
#  2   Product ID          73100 non-null  object
#  3   Category            73100 non-null  object
#  4   Region              73100 non-null  object
#  5   Inventory Level     73100 non-null  int64
#  6   Units Sold          73100 non-null  int64
#  7   Units Ordered       73100 non-null  int64
#  8   Demand Forecast     73100 non-null  float64
#  9   Price               73100 non-null  float64
#  10  Discount            73100 non-null  int64
#  11  Weather Condition   73100 non-null  object
#  12  Holiday/Promotion   73100 non-null  int64
#  13  Competitor Pricing  73100 non-null  float64
#  14  Seasonality         73100 non-null  object
# dtypes: float64(3), int64(5), object(7)
# memory usage: 8.4+ MB

# %%
# Initialize LabelEncoders for each column
obj1, obj2, obj3, obj4,obj5,obj6,obj7 = [LabelEncoder() for i in range(7)]

# Apply Label Encoding
data["Date"] = obj1.fit_transform(data["Date"])
data["Store ID"] = obj2.fit_transform(data["Store ID"])
data["Product ID"] = obj3.fit_transform(data["Product ID"])
data["Category"] = obj4.fit_transform(data["Category"])
data["Region"] = obj5.fit_transform(data["Region"])
data["Weather Condition"] = obj6.fit_transform(data["Weather Condition"])
data["Seasonality"] = obj7.fit_transform(data["Seasonality"])

# %%
data.corr()['Demand Forecast'].sort_values(ascending=False)
# Out:
# Demand Forecast       1.000000
# Units Sold            0.996853
# Inventory Level       0.588561
# Product ID            0.006659
# Store ID              0.005666
# Weather Condition     0.004768
# Discount              0.002338
# Competitor Pricing    0.000844
# Price                 0.000675
# Category              0.000495
# Holiday/Promotion    -0.000526
# Units Ordered        -0.001102
# Date                 -0.002125
# Region               -0.002467
# Seasonality          -0.003109
# Name: Demand Forecast, dtype: float64

# %%
data1=data.drop(["Date","Store ID","Product ID"],axis=1)
data1
# Out:
#        Category  Region  Inventory Level  Units Sold  Units Ordered  \
# 0             3       1              231         127             55
# 1             4       2              204         150             66
# 2             4       3              102          65             51
# 3             4       1              469          61            164
# 4             1       0              166          14            135
# ...         ...     ...              ...         ...            ...
# 73095         2       0               96           8            127
# 73096         4       1              313          51            101
# 73097         0       3              278          36            151
# 73098         4       0              374         264             21
# 73099         3       0              117           6            165
#
#        Demand Forecast  Price  Discount  Weather Condition  Holiday/Promotion  \
# 0               135.47  33.50        20                  1                  0
# 1               144.04  63.01        20                  3                  0
# 2                74.02  27.99        10                  3                  1
# 3                62.18  32.72        10                  0                  1
# 4                 9.26  73.64         0                  3                  0
# ...                ...    ...       ...                ...                ...
# 73095            18.46  73.73        20                  2                  0
# 73096            48.43  82.57        10                  0                  0
# 73097            39.65  11.11        10                  1                  0
# 73098           270.52  53.14        20                  1                  0
# 73099             2.33  78.39        20                  1                  1
#
#        Competitor Pricing  Seasonality
# 0                   29.69            0
# 1                   66.16            0
# 2                   31.32            2
# 3                   34.74            0
# 4                   68.95            2
# ...                   ...          ...
# 73095               72.45            3
# 73096               83.78            0
# 73097               10.91            3
# 73098               55.80            1
# 73099               79.52            1
#
# [73100 rows x 12 columns]

# %%
x=data1.drop(["Demand Forecast"],axis=1)
y=data1["Demand Forecast"]

# %%
x
# Out:
#        Category  Region  Inventory Level  Units Sold  Units Ordered  Price  \
# 0             3       1              231         127             55  33.50
# 1             4       2              204         150             66  63.01
# 2             4       3              102          65             51  27.99
# 3             4       1              469          61            164  32.72
# 4             1       0              166          14            135  73.64
# ...         ...     ...              ...         ...            ...    ...
# 73095         2       0               96           8            127  73.73
# 73096         4       1              313          51            101  82.57
# 73097         0       3              278          36            151  11.11
# 73098         4       0              374         264             21  53.14
# 73099         3       0              117           6            165  78.39
#
#        Discount  Weather Condition  Holiday/Promotion  Competitor Pricing  \
# 0            20                  1                  0               29.69
# 1            20                  3                  0               66.16
# 2            10                  3                  1               31.32
# 3            10                  0                  1               34.74
# 4             0                  3                  0               68.95
# ...         ...                ...                ...                 ...
# 73095        20                  2                  0               72.45
# 73096        10                  0                  0               83.78
# 73097        10                  1                  0               10.91
# 73098        20                  1                  0               55.80
# 73099        20                  1                  1               79.52
#
#        Seasonality
# 0                0
# 1                0
# 2                2
# 3                0
# 4                2
# ...            ...
# 73095            3
# 73096            0
# 73097            3
# 73098            1
# 73099            1
#
# [73100 rows x 11 columns]

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.3,random_state=42)

# %% [markdown]
#  ### Visualization of Target Variable (Demand Forecast)

# %%
# Plot distribution of target variable
plt.figure(figsize=(8,5))
sns.histplot(ytrain, kde=True, color='skyblue')
plt.title('Distribution of Demand Forecast (Training Set)')
plt.xlabel('Demand Forecast')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### model creation

# %% [markdown]
# ### Accuracy using RandomForestRegressor

# %%
rf=RandomForestRegressor(n_estimators=200,max_depth=10,random_state=42)

# %%
# rf.fit(xtrain,ytrain)

# %%
# After fitting RandomForest
importances = rf.feature_importances_
features = xtrain.columns

# Plotting feature importance
feat_importances = pd.Series(importances, index=features)
feat_importances.nlargest(10).plot(kind='barh', color='lightgreen', figsize=(8,6))
plt.title('Top 10 Important Features')
plt.xlabel('Feature Importance Score')
plt.show()


# Random Forest models can measure how much each feature contributes to the predictive performance.
# This code helps identify which features have the most influence on the model's predictions.
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[21], line 2
#       1 # After fitting RandomForest
# ----> 2 importances = rf.feature_importances_
#       3 features = xtrain.columns
#       5 # Plotting feature importance
#
# File ~\anaconda3\Lib\site-packages\sklearn\ensemble\_forest.py:673, in BaseForest.feature_importances_(self)
#     652 @property
#     653 def feature_importances_(self):
#     654     """
#     655     The impurity-based feature importances.
#     656
#    (...)
#     671         array of zeros.
#     672     """
# --> 673     check_is_fitted(self)
#     675     all_importances = Parallel(n_jobs=self.n_jobs, prefer="threads")(
#     676         delayed(getattr)(tree, "feature_importances_")
#     677         for tree in self.estimators_
#     678         if tree.tree_.node_count > 1
#     679     )
#     681     if not all_importances:
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1661, in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1658     raise TypeError("%s is not an estimator instance." % (estimator))
#    1660 if not _is_fitted(estimator, attributes, all_or_any):
# -> 1661     raise NotFittedError(msg % {"name": type(estimator).__name__})
#
# NotFittedError: This RandomForestRegressor instance is not fitted yet. Call 'fit' with appropriate arguments before using this estimator.

# %%
rf_ypred=rf.predict(xtest)
rf_ypred

# %% [markdown]
# ##### Mean Absolute Error (MAE)

# %%
from sklearn.metrics import mean_absolute_error
rf_mae = mean_absolute_error(ytest, rf_ypred)*100
rf_mae
# Mean Absolute Error (MAE)
# Measures the average absolute difference between predicted and actual values.

# %% [markdown]
# ### Mean Squared Error (MSE)

# %%
from sklearn.metrics import mean_squared_error

rf_mse = mean_squared_error(ytest, rf_ypred)*100
rf_mse
#  Mean Squared Error (MSE)
# Squares the errors before averaging — penalizes large errors more than MAE.

# %% [markdown]
# ### Root Mean Squared Error (RMSE)

# %%
import numpy as np
rf_rmse = np.sqrt(rf_mse)*100
rf_rmse
# Root Mean Squared Error (RMSE)
# Just the square root of MSE.

# Brings the units back to the original scale of the target variable.

# %% [markdown]
# #### R² Score (Coefficient of Determination)

# %%
# R² Score (Coefficient of Determination)
# Tells you how much of the variance in the target is explained by the model.

# Ranges from -∞ to 1.0. Closer to 1 = better.

from sklearn.metrics import r2_score

rf2 = r2_score(ytest, rf_ypred)*100
rf2

# %% [markdown]
# ### Cross-Validation Score

# %%
from sklearn.model_selection import cross_val_score

# 5-fold cross validation
scores = cross_val_score(rf, xtrain, ytrain, cv=5, scoring='r2')
print(f"Cross-Validation R2 Scores: {scores}")
print(f"Average R2 Score: {scores.mean():.4f}")

# %%
print(f"MAE: {rf_mae}")
print(f"MSE: {rf_mse}")
print(f"RMSE: {rf_rmse}")
print(f"R² Score: {rf2}")

# %%
rf.score(xtrain,ytrain)*100

# %%
rf.score(xtest,ytest)*100

# %% [markdown]
# ### Accuracy using Linear Regression

# %%
lr= LinearRegression()

# %%
lr.fit(xtrain,ytrain)

# %%
lr.score(xtrain,ytrain)*100

# %%
lr.score(xtest,ytest)*100

# %%
lr_ypred=lr.predict(xtest)
lr_ypred
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 lr_ypred=lr.predict(xtest)
#       2 lr_ypred
#
# NameError: name 'lr' is not defined

# %%
lr_mae = mean_absolute_error(ytest, lr_ypred)*100
lr_mae
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 lr_mae = mean_absolute_error(ytest, lr_ypred)*100
#       2 lr_mae
#
# NameError: name 'mean_absolute_error' is not defined

# %%
lr_mse = mean_squared_error(ytest, lr_ypred)*100
lr_mse
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 lr_mse = mean_squared_error(ytest, lr_ypred)*100
#       2 lr_mse
#
# NameError: name 'mean_squared_error' is not defined

# %%
lr_rmse = np.sqrt(lr_mse)*100
lr_rmse
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 lr_rmse = np.sqrt(lr_mse)*100
#       2 lr_rmse
#
# NameError: name 'lr_mse' is not defined

# %%
lr2 = r2_score(ytest, lr_ypred)*100
lr2

# %%
print(f"MAE: {lr_mae`}")
print(f"MSE: {lr_mse}")
print(f"RMSE: {lr_rmse}")
print(f"R² Score: {lr2}")

# %% [markdown]
# ### Accuracy using DecisionTreeRegressor

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dr=DecisionTreeRegressor()

# %%
dr.fit(xtrain,ytrain)

# %%
dr.score(xtrain,ytrain)*100

# %%
dr.score(xtest,ytest)*100

# %%
dr_ypred=dr.predict(xtest)
dr_ypred

# %%
dr_mae = mean_absolute_error(ytest, dr_ypred)*100
dr_mae

# %%
dr_mse = mean_squared_error(ytest, dr_ypred)
dr_mse
# Out:
# 153.6655978157775

# %%
dr_rmse = np.sqrt(dr_mse)
dr_rmse
# Out:
# 12.396192875870296

# %%
c
# Out:
# 98.71462404147728

# %%
print(f"MAE: {dr_mae}")
print(f"MSE: {dr_mse}")
print(f"RMSE: {dr_rmse}")
print(f"R² Score: {dr2}")
# Out:
# MAE: 1011.1005471956224
# MSE: 153.6655978157775
# RMSE: 12.396192875870296
# R² Score: 98.71462404147728

# %%
print(xtrain.shape,ytrain.shape,xtest.shape)
# Out:
# (51170, 11) (51170,) (21930, 11)

# %% [markdown]
# #### save to pickle

# %%
import pickle

# %%
filename="trained_model.sav" # it is file to save the model that is created by ourself
pickle.dump(rf,open(filename,"wb"))
            # wb is for writing
# loading the saved model
loaded_model=pickle.load(open(filename,"rb"))
                         # rb is for read


loaded_model
# Out:
# RandomForestRegressor(max_depth=10, n_estimators=200, random_state=42)

# %%
# !pip install gradio
# Out:
# Requirement already satisfied: gradio in c:\users\adythya ani\anaconda3\lib\site-packages (5.23.1)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in c:\users\adythya ani\anaconda3\lib\site-packages (from gradio) (23.2.1)
# Requirement already satisfied: anyio<5.0,>=3.0 in c:\users\adythya ani\anaconda3\lib\site-packages (from gradio) (4.2.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in c:\users\adythya ani\anaconda3\lib\site-packages (from gradio) (0.115.12)
# Requirement already satisfied: ffmpy in c:\users\adythya ani\anaconda3\lib\site-packages (from gradio) (0.5.0)
# Requirement already satisfied: gradio-client==1.8.0 in c:\users\adythya ani\anaconda3\lib\site-packages (from gradio) (1.8.0)
# Requirement already satisfied: groovy~=0.1 in c:\users\adythya ani\anaconda3\lib\site-packages (from gradio) (0.1.2)
# Requirement already satisfied: httpx>=0.24.1 in c:\users\adythya ani\anaconda3\lib\site-packages (from gradio) (0.27.0)
# Requirement already satisfied: huggingface-hub>=0.28.1 in c:\users\adythya ani\anaconda3\lib\site-packages (from gradio) (0.29.3)
# Requirement already satisfied: jinja2<4.0 in c:\users\adythya ani\anaconda3\lib\site-packages (from gradio) (3.1.4)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in c:\users\adythya ani\anaconda3\lib\site-packages (from gradio) (2.1.3)
# Requirement already satisfied: numpy<3.0,>=1.0 in c:\users\adythya ani\anaconda3\lib\site-packages (from gradio) (1.26.4)
# Requirement already satisfied: orjson~=3.0 in c:\users\adythya ani\anaconda3\lib\site-packages (from gradio) (3.10.16)
# Requirement already satisfied: packaging in c:\users\adythya ani\anaconda3\lib\site-packages (from gradio) (24.1)
# Requirement already satisfied: pandas<3.0,>=1.0 in c:\users\adythya ani\anaconda3\lib\site-packages (from gradio) (2.2.2)
# Requirement already satisfied: pillow<12.0,>=8.0 in c:\users\adythya ani\anaconda3\lib\site-packages (from gradio) (10.4.0)
# Requirement already satisfied: pydantic>=2.0 in c:\users\adythya ani\anaconda3\lib\site-packages (from gradio) (2.8.2)
# Requirement already satisfied: pydub in c:\users\adythya ani\anaconda3\lib\site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in c:\users\adythya ani\anaconda3\lib\site-packages (from gradio) (0.0.20)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in c:\users\adythya ani\anaconda3\lib\site-packages (from gradio) (6.0.1)
# Requirement already satisfied: ruff>=0.9.3 in c:\users\adythya ani\anaconda3\lib\site-packages (from gradio) (0.11.2)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in c:\users\adythya ani\anaconda3\lib\site-packages (from gradio) (0.1.6)
# Requirement already satisfied: semantic-version~=2.0 in c:\users\adythya ani\anaconda3\lib\site-packages (from gradio) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in c:\users\adythya ani\anaconda3\lib\site-packages (from gradio) (0.46.1)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in c:\users\adythya ani\anaconda3\lib\site-packages (from gradio) (0.13.2)
# Requirement already satisfied: typer<1.0,>=0.12 in c:\users\adythya ani\anaconda3\lib\site-packages (from gradio) (0.15.2)
# Requirement already satisfied: typing-extensions~=4.0 in c:\users\adythya ani\anaconda3\lib\site-packages (from gradio) (4.11.0)
# Requirement already satisfied: uvicorn>=0.14.0 in c:\users\adythya ani\anaconda3\lib\site-packages (from gradio) (0.34.0)
# Requirement already satisfied: fsspec in c:\users\adythya ani\anaconda3\lib\site-packages (from gradio-client==1.8.0->gradio) (2024.6.1)
# Requirement already satisfied: websockets<16.0,>=10.0 in c:\users\adythya ani\anaconda3\lib\site-packages (from gradio-client==1.8.0->gradio) (15.0.1)
# Requirement already satisfied: idna>=2.8 in c:\users\adythya ani\anaconda3\lib\site-packages (from anyio<5.0,>=3.0->gradio) (3.7)
# Requirement already satisfied: sniffio>=1.1 in c:\users\adythya ani\anaconda3\lib\site-packages (from anyio<5.0,>=3.0->gradio) (1.3.0)
# Requirement already satisfied: certifi in c:\users\adythya ani\anaconda3\lib\site-packages (from httpx>=0.24.1->gradio) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\users\adythya ani\anaconda3\lib\site-packages (from httpx>=0.24.1->gradio) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\adythya ani\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.24.1->gradio) (0.14.0)
# Requirement already satisfied: filelock in c:\users\adythya ani\anaconda3\lib\site-packages (from huggingface-hub>=0.28.1->gradio) (3.13.1)
# Requirement already satisfied: requests in c:\users\adythya ani\anaconda3\lib\site-packages (from huggingface-hub>=0.28.1->gradio) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\adythya ani\anaconda3\lib\site-packages (from huggingface-hub>=0.28.1->gradio) (4.66.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\adythya ani\anaconda3\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\adythya ani\anaconda3\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\adythya ani\anaconda3\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2023.3)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\adythya ani\anaconda3\lib\site-packages (from pydantic>=2.0->gradio) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\adythya ani\anaconda3\lib\site-packages (from pydantic>=2.0->gradio) (2.20.1)
# Requirement already satisfied: click>=8.0.0 in c:\users\adythya ani\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\adythya ani\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\adythya ani\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio) (13.7.1)
# Requirement already satisfied: colorama in c:\users\adythya ani\anaconda3\lib\site-packages (from click>=8.0.0->typer<1.0,>=0.12->gradio) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\adythya ani\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\adythya ani\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\adythya ani\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.15.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\adythya ani\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.28.1->gradio) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\adythya ani\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.28.1->gradio) (2.2.3)
# Requirement already satisfied: mdurl~=0.1 in c:\users\adythya ani\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.0)

# %%
import gradio as gr
import pickle
import numpy as np

# Load the trained model
model = pickle.load(open(r"C:\Users\ADYTHYA ANI\trained_model.sav", "rb"))

# Mapping for dropdown options to encoded numbers
category_mapping = {
    "Electronics": 0,
    "Clothing": 1,
    "Food": 2,
    "Furniture": 3,
    "Books": 4
}

region_mapping = {
    "North": 0,
    "South": 1,
    "East": 2,
    "West": 3,
    "Central": 4
}

weather_mapping = {
    "Sunny": 0,
    "Rainy": 1,
    "Snowy": 2,
    "Cloudy": 3,
    "Stormy": 4
}

seasonality_mapping = {
    "Low": 0,
    "Medium": 1,
    "High": 2
}

# Define the prediction function
def demand_forecast(Category, Region, Inventory_Level, Units_Sold, Units_Ordered,
                    Price, Discount, Weather_Condition, Holiday_Promotion,
                    Competitor_Pricing, Seasonality):
    
    input_data = np.array([
        category_mapping[Category],
        region_mapping[Region],
        Inventory_Level,
        Units_Sold,
        Units_Ordered,
        Price,
        Discount,
        weather_mapping[Weather_Condition],
        Holiday_Promotion,
        Competitor_Pricing,
        seasonality_mapping[Seasonality]
    ]).reshape(1, -1)

    prediction = model.predict(input_data)[0]

    # Interpretation
    if prediction > 150:
        interpretation = "Very high expected demand"
    elif prediction > 100:
        interpretation = "High expected demand"
    elif prediction > 50:
        interpretation = "Moderate demand"
    else:
        interpretation = "Low expected demand"

    return f"Predicted Demand Forecast: {prediction:.2f} ({interpretation})"

# Gradio Interface
iface = gr.Interface(
    fn=demand_forecast,
    inputs=[
        gr.Dropdown(list(category_mapping.keys()), label="Category"),
        gr.Dropdown(list(region_mapping.keys()), label="Region"),
        gr.Number(label="Inventory Level"),
        gr.Number(label="Units Sold"),
        gr.Number(label="Units Ordered"),
        gr.Number(label="Price"),
        gr.Number(label="Discount"),
        gr.Dropdown(list(weather_mapping.keys()), label="Weather Condition"),
        gr.Radio(choices=[0, 1], label="Holiday/Promotion (0: No, 1: Yes)"),
        gr.Number(label="Competitor Pricing"),
        gr.Dropdown(list(seasonality_mapping.keys()), label="Seasonality"),
    ],
    outputs="text",
    title="🛒 Retail Demand Forecast Predictor",
    description="Fill in product and store details to predict demand forecast easily!"
)

iface.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7862
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7862/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
